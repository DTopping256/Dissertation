# %%
import matplotlib.pyplot as plt
import IPython.display as ipd
import numpy as np
import sys
import time
import math
from itertools import combinations
from functools import reduce
import constraint as c 

# Allows me to import my modules
sys.path.append('./modules')
from audio_utils import *
import data_augmentation as data_aug
# Out:
# Attempting to read settings file...
# 	Read successfully!

# %%
augmented_fd = get_file_classes("pre_multiclass_augmented")

# %%
cropped_fd = get_file_classes("cropped")

# %%
print("cropped amount:", len(cropped_fd), "\tpre_auged amount:", len(augmented_fd))
# Out:
# cropped amount: 147 	pre_auged amount: 18228

# %%
hit_breakdown = {hl: [] for hl in SETTINGS.label["hit_label"]}
for hl in SETTINGS.label["hit_label"]:
    for kl in SETTINGS.hierarchy[hl].keys():
        for tl in SETTINGS.hierarchy[hl][kl]:
            hit_breakdown[hl].append("-".join([kl, tl]))

# %%
hit_breakdown
# Out:
# {'beater': ['bass_drum-normal'],
#  'stick': ['high_tom-normal',
#   'crash-normal',
#   'low_tom-normal',
#   'ride-normal',
#   'ride-bell',
#   'hi_hat-normal',
#   'hi_hat-open',
#   'snare-normal',
#   'mid_tom-normal']}

# %%
def unique_kit_class(*ts):
    current_kt = ts[0].split("-")[0]
    for t in ts[1:]:
        kt = t.split("-")[0]
        if kt == current_kt:
            return False
    return True

# %%
def kit_combinations():
    hit_combos = SETTINGS.data["multiclassed"]["hit_combinations"]
    hit_breakdown = {hl: [] for hl in SETTINGS.label["hit_label"]}
    for hl in SETTINGS.label["hit_label"]:
        for kl in SETTINGS.hierarchy[hl].keys():
            for tl in SETTINGS.hierarchy[hl][kl]:
                hit_breakdown[hl].append("-".join([kl, tl]))
    kit_combos = []
    for hc in hit_combos:
        prob = c.Problem()
        var_i = 0
        for ht in hc:
            prob.addVariable(str(var_i), hit_breakdown[ht])
            var_i += 1
        # Kit type contraint (they must be unique)
        prob.addConstraint(unique_kit_class)
        # Remove permutations of hits
        kit_combo_subset = list(reduce(lambda acc, x: [*acc, set(x.values())] if set(x.values()) not in acc else acc, prob.getSolutions(), []))
        kit_combo_subset = list(filter(lambda x: x not in kit_combos, kit_combo_subset))
        kit_combos.extend(kit_combo_subset)
    return kit_combos

# %%
kcs = kit_combinations()

# %%
kltl_count = {}
for kltl in hit_breakdown["beater"]+hit_breakdown["stick"]:
    count = 0
    for kc in kcs:
        if kltl in kc:
            count += 1
    kltl_count[kltl] = count

# %%
kltl_count
# Out:
# {'bass_drum-normal': 55,
#  'crash-normal': 19,
#  'hi_hat-normal': 18,
#  'hi_hat-open': 18,
#  'high_tom-normal': 19,
#  'low_tom-normal': 19,
#  'mid_tom-normal': 19,
#  'ride-bell': 18,
#  'ride-normal': 18,
#  'snare-normal': 19}

# %%
## SHOULD BE 107 NOT 119, if the latter restart the terminal as some kit combos were repeated
print(len(kcs))
kcs
# Out:
# 98
# [{'bass_drum-normal'},
#  {'mid_tom-normal'},
#  {'snare-normal'},
#  {'hi_hat-open'},
#  {'hi_hat-normal'},
#  {'ride-bell'},
#  {'ride-normal'},
#  {'low_tom-normal'},
#  {'crash-normal'},
#  {'high_tom-normal'},
#  {'bass_drum-normal', 'mid_tom-normal'},
#  {'bass_drum-normal', 'snare-normal'},
#  {'bass_drum-normal', 'hi_hat-open'},
#  {'bass_drum-normal', 'hi_hat-normal'},
#  {'bass_drum-normal', 'ride-bell'},
#  {'bass_drum-normal', 'ride-normal'},
#  {'bass_drum-normal', 'low_tom-normal'},
#  {'bass_drum-normal', 'crash-normal'},
#  {'bass_drum-normal', 'high_tom-normal'},
#  {'mid_tom-normal', 'snare-normal'},
#  {'hi_hat-open', 'mid_tom-normal'},
#  {'hi_hat-normal', 'mid_tom-normal'},
#  {'mid_tom-normal', 'ride-bell'},
#  {'mid_tom-normal', 'ride-normal'},
#  {'low_tom-normal', 'mid_tom-normal'},
#  {'crash-normal', 'mid_tom-normal'},
#  {'high_tom-normal', 'mid_tom-normal'},
#  {'hi_hat-open', 'snare-normal'},
#  {'hi_hat-normal', 'snare-normal'},
#  {'ride-bell', 'snare-normal'},
#  {'ride-normal', 'snare-normal'},
#  {'low_tom-normal', 'snare-normal'},
#  {'crash-normal', 'snare-normal'},
#  {'high_tom-normal', 'snare-normal'},
#  {'hi_hat-open', 'ride-bell'},
#  {'hi_hat-open', 'ride-normal'},
#  {'hi_hat-open', 'low_tom-normal'},
#  {'crash-normal', 'hi_hat-open'},
#  {'hi_hat-open', 'high_tom-normal'},
#  {'hi_hat-normal', 'ride-bell'},
#  {'hi_hat-normal', 'ride-normal'},
#  {'hi_hat-normal', 'low_tom-normal'},
#  {'crash-normal', 'hi_hat-normal'},
#  {'hi_hat-normal', 'high_tom-normal'},
#  {'low_tom-normal', 'ride-bell'},
#  {'crash-normal', 'ride-bell'},
#  {'high_tom-normal', 'ride-bell'},
#  {'low_tom-normal', 'ride-normal'},
#  {'crash-normal', 'ride-normal'},
#  {'high_tom-normal', 'ride-normal'},
#  {'crash-normal', 'low_tom-normal'},
#  {'high_tom-normal', 'low_tom-normal'},
#  {'crash-normal', 'high_tom-normal'},
#  {'bass_drum-normal', 'mid_tom-normal'},
#  {'bass_drum-normal', 'mid_tom-normal', 'snare-normal'},
#  {'bass_drum-normal', 'hi_hat-open', 'mid_tom-normal'},
#  {'bass_drum-normal', 'hi_hat-normal', 'mid_tom-normal'},
#  {'bass_drum-normal', 'mid_tom-normal', 'ride-bell'},
#  {'bass_drum-normal', 'mid_tom-normal', 'ride-normal'},
#  {'bass_drum-normal', 'low_tom-normal', 'mid_tom-normal'},
#  {'bass_drum-normal', 'crash-normal', 'mid_tom-normal'},
#  {'bass_drum-normal', 'high_tom-normal', 'mid_tom-normal'},
#  {'bass_drum-normal', 'snare-normal'},
#  {'bass_drum-normal', 'hi_hat-open', 'snare-normal'},
#  {'bass_drum-normal', 'hi_hat-normal', 'snare-normal'},
#  {'bass_drum-normal', 'ride-bell', 'snare-normal'},
#  {'bass_drum-normal', 'ride-normal', 'snare-normal'},
#  {'bass_drum-normal', 'low_tom-normal', 'snare-normal'},
#  {'bass_drum-normal', 'crash-normal', 'snare-normal'},
#  {'bass_drum-normal', 'high_tom-normal', 'snare-normal'},
#  {'bass_drum-normal', 'hi_hat-open'},
#  {'bass_drum-normal', 'hi_hat-normal', 'hi_hat-open'},
#  {'bass_drum-normal', 'hi_hat-open', 'ride-bell'},
#  {'bass_drum-normal', 'hi_hat-open', 'ride-normal'},
#  {'bass_drum-normal', 'hi_hat-open', 'low_tom-normal'},
#  {'bass_drum-normal', 'crash-normal', 'hi_hat-open'},
#  {'bass_drum-normal', 'hi_hat-open', 'high_tom-normal'},
#  {'bass_drum-normal', 'hi_hat-normal'},
#  {'bass_drum-normal', 'hi_hat-normal', 'ride-bell'},
#  {'bass_drum-normal', 'hi_hat-normal', 'ride-normal'},
#  {'bass_drum-normal', 'hi_hat-normal', 'low_tom-normal'},
#  {'bass_drum-normal', 'crash-normal', 'hi_hat-normal'},
#  {'bass_drum-normal', 'hi_hat-normal', 'high_tom-normal'},
#  {'bass_drum-normal', 'ride-bell'},
#  {'bass_drum-normal', 'ride-bell', 'ride-normal'},
#  {'bass_drum-normal', 'low_tom-normal', 'ride-bell'},
#  {'bass_drum-normal', 'crash-normal', 'ride-bell'},
#  {'bass_drum-normal', 'high_tom-normal', 'ride-bell'},
#  {'bass_drum-normal', 'ride-normal'},
#  {'bass_drum-normal', 'low_tom-normal', 'ride-normal'},
#  {'bass_drum-normal', 'crash-normal', 'ride-normal'},
#  {'bass_drum-normal', 'high_tom-normal', 'ride-normal'},
#  {'bass_drum-normal', 'low_tom-normal'},
#  {'bass_drum-normal', 'crash-normal', 'low_tom-normal'},
#  {'bass_drum-normal', 'high_tom-normal', 'low_tom-normal'},
#  {'bass_drum-normal', 'crash-normal'},
#  {'bass_drum-normal', 'crash-normal', 'high_tom-normal'},
#  {'bass_drum-normal', 'high_tom-normal'}]

# %%
fds = augmented_fd
fd_categorised = {kltl: [] for kltl in hit_breakdown["beater"]+hit_breakdown["stick"]}
for fd in fds:
    for kltl in fd_categorised.keys():
        kl, tl = kltl.split("-")
        if (kl in fd["labels"]["kit_label"] and tl in fd["labels"]["tech_label"]):
            fd_categorised[kltl].append(fd)
fd_categorised
# Out:
# {'bass_drum-normal': [{'augmentations': {'pre_augs': ['amplitude']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude\\beater\\bass_drum\\normal\\0.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude\\beater\\bass_drum\\normal\\1.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude\\beater\\bass_drum\\normal\\10.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude\\beater\\bass_drum\\normal\\11.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude\\beater\\bass_drum\\normal\\12.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude\\beater\\bass_drum\\normal\\13.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude\\beater\\bass_drum\\normal\\14.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude\\beater\\bass_drum\\normal\\15.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude\\beater\\bass_drum\\normal\\16.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude\\beater\\bass_drum\\normal\\17.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude\\beater\\bass_drum\\normal\\18.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude\\beater\\bass_drum\\normal\\19.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude\\beater\\bass_drum\\normal\\2.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude\\beater\\bass_drum\\normal\\20.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude\\beater\\bass_drum\\normal\\21.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude\\beater\\bass_drum\\normal\\22.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude\\beater\\bass_drum\\normal\\23.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude\\beater\\bass_drum\\normal\\24.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude\\beater\\bass_drum\\normal\\25.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude\\beater\\bass_drum\\normal\\26.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude\\beater\\bass_drum\\normal\\27.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude\\beater\\bass_drum\\normal\\28.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude\\beater\\bass_drum\\normal\\29.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude\\beater\\bass_drum\\normal\\3.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude\\beater\\bass_drum\\normal\\30.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude\\beater\\bass_drum\\normal\\31.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude\\beater\\bass_drum\\normal\\32.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude\\beater\\bass_drum\\normal\\33.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude\\beater\\bass_drum\\normal\\34.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude\\beater\\bass_drum\\normal\\35.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude\\beater\\bass_drum\\normal\\36.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude\\beater\\bass_drum\\normal\\37.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude\\beater\\bass_drum\\normal\\38.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude\\beater\\bass_drum\\normal\\39.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude\\beater\\bass_drum\\normal\\4.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude\\beater\\bass_drum\\normal\\40.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude\\beater\\bass_drum\\normal\\41.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude\\beater\\bass_drum\\normal\\42.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude\\beater\\bass_drum\\normal\\43.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude\\beater\\bass_drum\\normal\\5.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude\\beater\\bass_drum\\normal\\6.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude\\beater\\bass_drum\\normal\\7.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude\\beater\\bass_drum\\normal\\8.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude\\beater\\bass_drum\\normal\\9.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\0.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\1.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\10.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\100.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\101.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\102.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\103.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\104.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\105.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\106.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\107.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\108.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\109.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\11.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\110.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\111.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\112.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\113.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\114.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\115.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\116.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\117.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\118.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\119.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\12.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\120.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\121.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\122.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\123.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\124.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\125.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\126.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\127.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\128.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\129.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\13.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\130.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\131.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\132.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\133.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\134.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\135.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\136.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\137.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\138.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\139.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\14.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\140.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\141.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\142.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\143.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\144.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\145.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\146.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\147.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\148.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\149.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\15.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\150.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\151.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\152.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\153.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\154.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\155.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\156.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\157.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\158.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\159.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\16.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\160.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\161.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\162.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\163.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\164.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\165.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\166.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\167.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\168.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\169.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\17.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\170.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\171.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\172.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\173.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\174.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\175.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\18.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\19.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\2.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\20.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\21.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\22.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\23.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\24.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\25.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\26.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\27.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\28.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\29.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\3.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\30.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\31.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\32.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\33.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\34.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\35.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\36.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\37.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\38.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\39.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\4.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\40.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\41.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\42.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\43.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\44.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\45.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\46.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\47.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\48.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\49.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\5.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\50.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\51.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\52.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\53.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\54.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\55.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\56.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\57.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\58.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\59.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\6.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\amplitude-pitch\\beater\\bass_drum\\normal\\60.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['amplitude', 'pitch']},
# ...
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\100.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\101.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\102.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\103.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\104.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\105.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\106.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\107.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\108.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\109.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\11.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\110.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\111.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\112.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\113.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\114.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\115.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\116.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\117.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\118.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\119.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\12.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\120.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\121.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\122.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\123.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\124.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\125.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\126.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\127.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\128.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\129.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\13.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\130.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\131.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\132.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\133.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\134.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\135.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\136.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\137.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\138.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\139.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\14.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\140.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\141.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\142.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\143.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\15.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\16.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\17.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\18.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\19.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\2.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\20.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\21.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\22.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\23.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\24.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\25.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {'pre_augs': ['pitch', 'translate']},
#    'filepath': 'audio_data\\pre-multiclass_augmented_data\\pitch-translate\\stick\\snare\\normal\\26.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   ...]}

# %%
kltl_samples = {kltl: len(fd_categorised[kltl]) for kltl in hit_breakdown["beater"]+hit_breakdown["stick"]}
for kltl, amount in kltl_samples.items():
    count = kltl_count[kltl]
    print(kltl, amount, "/", count, "=", math.floor(amount/count))
# Out:
# low_tom-normal 1736 / 19 = 91
# hi_hat-open 1612 / 18 = 89
# mid_tom-normal 1364 / 19 = 71
# ride-bell 1488 / 18 = 82
# ride-normal 1488 / 18 = 82
# hi_hat-normal 1364 / 18 = 75
# bass_drum-normal 1364 / 55 = 24
# snare-normal 1116 / 19 = 58
# crash-normal 1736 / 19 = 91
# high_tom-normal 1488 / 19 = 78

# %%
## Multiclassed -- (every augmentation comb possible, many times with no non-uniques)

kltl_iterations = {kltl: 0 for kltl in hit_breakdown["beater"]+hit_breakdown["stick"]}
for i in range(31):
    multiclassed_data = []
    for kit_combo_set in kcs:
        kc = [kltl for kltl in kit_combo_set]
        kc.sort()
        samples = np.zeros(12000, dtype=np.float32)
        labels=dict()
        augmentations=dict()
        for kltl in kc:
            file_i = kltl_iterations[kltl]
            fd = fd_categorised[kltl][file_i]
            filepath = fd["filepath"]
            try:
                new_samples = np.loadtxt(fname=filepath, dtype=np.float32)
                pad_len = 12000-len(new_samples)
                new_samples = np.pad(new_samples, (pad_len, 0), "constant", constant_values=(0))
                samples = samples + new_samples
                kltl_iterations[kltl] = (kltl_iterations[kltl] + 1) % len(fd_categorised[kltl])
            except:
                print("skipped", *sys.exc_info())
                continue
            for l in fd["labels"].keys():
                if (l not in labels.keys() and l in fd["labels"].keys()):
                    labels.update({l: [x for x in fd["labels"][l]]})
                elif (l in fd["labels"].keys()):
                    labels.update({l: labels[l]+fd["labels"][l]})
            for a in fd["augmentations"].keys():
                if (a not in augmentations.keys() and a in fd["augmentations"].keys()):
                    augmentations.update({a: [y for y in fd["augmentations"][a]]})
                elif (a in fd["augmentations"].keys()):
                    augmentations.update({a: augmentations[a]+fd["augmentations"][a]})
        multiclassed_data.append(Sample_data(labels={k:v for k,v in labels.items()}, augmentations={k:v for k,v in augmentations.items()}, data=samples, rate=SETTINGS.data["cropped"]["save_sampling_rate"]))
    save_data("multiclassed", data_set=multiclassed_data, verbose=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-03f54386f15f> in <module>
#       1 ## Multiclassed -- (every augmentation comb possible, many times with no non-uniques)
#       2
# ----> 3 kltl_iterations = {kltl: 0 for kltl in hit_breakdown["beater"]+hit_breakdown["stick"]}
#       4 for i in range(31):
#       5     multiclassed_data = []
#
# NameError: name 'hit_breakdown' is not defined

# %%
multiclassed_data[12].labels
# Out:
# {'hit_label': ['beater', 'stick'],
#  'kit_label': ['bass_drum', 'crash'],
#  'tech_label': ['normal', 'normal']}

# %%
multiclassed_data[12].augmentations
# Out:
# {'pre_augs': ['amplitude', 'pitch', 'translate', 'pitch', 'translate']}

# %%
plt.plot(multiclassed_data[12].data)
plt.show()
ipd.Audio(multiclassed_data[12].data, rate=48000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
len(multiclassed_data)
# Out:
# 107

# %%
multiclassed_data[0].augmentations["pre_augs"]
# Out:
# ['amplitude', 'pitch', 'translate']

# %%
pre_aug_stacks = data_aug.get_aug_stacks(data_aug.PRE_MULTI_AUGS)
print(len(pre_aug_stacks), pre_aug_stacks)
# Out:
# 7 [['amplitude'], ['pitch'], ['translate'], ['amplitude', 'pitch'], ['amplitude', 'translate'], ['pitch', 'translate'], ['amplitude', 'pitch', 'translate']]

# %%
## Multiclassed per aug -- only audio which are in the same augmentation stack are combined
kltl_iterations = {kltl: 0 for kltl in hit_breakdown["beater"]+hit_breakdown["stick"]}
for aug_stack in pre_aug_stacks:
    fd_categorised_subset = {kltl: list(filter(lambda fd: set(fd["augmentations"]["pre_augs"]) == set(aug_stack), v)) for kltl, v in fd_categorised.items()}
    print(aug_stack)
    for kltl in kltl_iterations.keys():
        print(kltl, ":", len(fd_categorised_subset[kltl]), "/", len(fd_categorised[kltl]))
    multiclassed_data_per_aug = []
    for kit_combo_set in kcs:
        kc = [kltl for kltl in kit_combo_set]
        kc.sort()
        samples = np.zeros(12000, dtype=np.float32)
        labels=dict()
        augmentations=dict()
        for kltl in kc:
            file_i = kltl_iterations[kltl]
            fd = fd_categorised_subset[kltl][file_i]
            kltl_iterations[kltl] = (kltl_iterations[kltl] + 1) % len(fd_categorised_subset[kltl])
            filepath = fd["filepath"]
            try:
                new_samples = np.loadtxt(fname=filepath, dtype=np.float32)
                pad_len = 12000-len(new_samples)
                new_samples = np.pad(new_samples, (pad_len, 0), "constant", constant_values=(0))
                samples = samples + new_samples
            except:
                print("skipped", *sys.exc_info())
                continue
            for l in LABELS:
                if (l not in labels.keys() and l in fd["labels"].keys()):
                    labels.update({l: [x for x in fd["labels"][l]]})
                elif (l in fd["labels"].keys()):
                    labels.update({l: labels[l]+fd["labels"][l]})
            for a in AUG_KEYS:
                if (a not in augmentations.keys() and a in fd["augmentations"].keys()):
                    augmentations.update({a: [y for y in fd["augmentations"][a]]})
                elif (a in fd["augmentations"].keys()):
                    augmentations.update({a: augmentations[a]+fd["augmentations"][a]})
        multiclassed_data_per_aug.append(Sample_data(labels={k:v for k,v in labels.items()}, augmentations={k:v for k,v in augmentations.items()}, data=samples, rate=SETTINGS.data["cropped"]["save_sampling_rate"]))
    save_data("multiclassed_per_aug", data_set=multiclassed_data_per_aug, verbose=True)
# Out:
# ['amplitude']
# crash-normal : 40 / 1240
# bass_drum-normal : 40 / 1240
# snare-normal : 40 / 1240
# mid_tom-normal : 40 / 1240
# ride-normal : 40 / 1240
# ride-bell : 40 / 1240
# hi_hat-open : 40 / 1240
# hi_hat-normal : 40 / 1240
# high_tom-normal : 40 / 1240
# splash-normal : 40 / 1240
# low_tom-normal : 40 / 1240
# Attempting to save multiclassed_per_aug data and labels...
# 	Saved: 107/107 files.
# ['pitch']
# crash-normal : 40 / 1240
# bass_drum-normal : 40 / 1240
# snare-normal : 40 / 1240
# mid_tom-normal : 40 / 1240
# ride-normal : 40 / 1240
# ride-bell : 40 / 1240
# hi_hat-open : 40 / 1240
# hi_hat-normal : 40 / 1240
# high_tom-normal : 40 / 1240
# splash-normal : 40 / 1240
# low_tom-normal : 40 / 1240
# Attempting to save multiclassed_per_aug data and labels...
# 	Saved: 107/107 files.
# ['translate']
# crash-normal : 40 / 1240
# bass_drum-normal : 40 / 1240
# snare-normal : 40 / 1240
# mid_tom-normal : 40 / 1240
# ride-normal : 40 / 1240
# ride-bell : 40 / 1240
# hi_hat-open : 40 / 1240
# hi_hat-normal : 40 / 1240
# high_tom-normal : 40 / 1240
# splash-normal : 40 / 1240
# low_tom-normal : 40 / 1240
# Attempting to save multiclassed_per_aug data and labels...
# 	Saved: 107/107 files.
# ['amplitude', 'pitch']
# crash-normal : 160 / 1240
# bass_drum-normal : 160 / 1240
# snare-normal : 160 / 1240
# mid_tom-normal : 160 / 1240
# ride-normal : 160 / 1240
# ride-bell : 160 / 1240
# hi_hat-open : 160 / 1240
# hi_hat-normal : 160 / 1240
# high_tom-normal : 160 / 1240
# splash-normal : 160 / 1240
# low_tom-normal : 160 / 1240
# Attempting to save multiclassed_per_aug data and labels...
# 	Saved: 107/107 files.
# ['amplitude', 'translate']
# crash-normal : 160 / 1240
# bass_drum-normal : 160 / 1240
# snare-normal : 160 / 1240
# mid_tom-normal : 160 / 1240
# ride-normal : 160 / 1240
# ride-bell : 160 / 1240
# hi_hat-open : 160 / 1240
# hi_hat-normal : 160 / 1240
# high_tom-normal : 160 / 1240
# splash-normal : 160 / 1240
# low_tom-normal : 160 / 1240
# Attempting to save multiclassed_per_aug data and labels...
# 	Saved: 107/107 files.
# ['pitch', 'translate']
# crash-normal : 160 / 1240
# bass_drum-normal : 160 / 1240
# snare-normal : 160 / 1240
# mid_tom-normal : 160 / 1240
# ride-normal : 160 / 1240
# ride-bell : 160 / 1240
# hi_hat-open : 160 / 1240
# hi_hat-normal : 160 / 1240
# high_tom-normal : 160 / 1240
# splash-normal : 160 / 1240
# low_tom-normal : 160 / 1240
# Attempting to save multiclassed_per_aug data and labels...
# 	Saved: 107/107 files.
# ['amplitude', 'pitch', 'translate']
# crash-normal : 640 / 1240
# bass_drum-normal : 640 / 1240
# snare-normal : 640 / 1240
# mid_tom-normal : 640 / 1240
# ride-normal : 640 / 1240
# ride-bell : 640 / 1240
# hi_hat-open : 640 / 1240
# hi_hat-normal : 640 / 1240
# high_tom-normal : 640 / 1240
# splash-normal : 640 / 1240
# low_tom-normal : 640 / 1240
# Attempting to save multiclassed_per_aug data and labels...
# 	Saved: 107/107 files.
# ['amplitude']
# crash-normal : 40 / 1240
# bass_drum-normal : 40 / 1240
# snare-normal : 40 / 1240
# mid_tom-normal : 40 / 1240
# ride-normal : 40 / 1240
# ride-bell : 40 / 1240
# hi_hat-open : 40 / 1240
# hi_hat-normal : 40 / 1240
# high_tom-normal : 40 / 1240
# splash-normal : 40 / 1240
# low_tom-normal : 40 / 1240
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-16-bcbe0ece48d1> in <module>
#      16             for kltl in kc:
#      17                 file_i = kltl_iterations[kltl]
# ---> 18                 fd = fd_categorised_subset[kltl][file_i]
#      19                 kltl_iterations[kltl] = (kltl_iterations[kltl] + 1) % len(fd_categorised_subset[kltl])
#      20                 filepath = fd["filepath"]
#
# IndexError: list index out of range

# %%
fd_categorised_no_augs = {kltl: [] for kltl in hit_breakdown["beater"]+hit_breakdown["stick"]}
for fd in cropped_fd:
    for kltl in fd_categorised_no_augs.keys():
        kl, tl = kltl.split("-")
        if (kl in fd["labels"]["kit_label"] and tl in fd["labels"]["tech_label"]):
            fd_categorised_no_augs[kltl].append(fd)
fd_categorised_no_augs
# Out:
# {'bass_drum-normal': [{'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\0.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\1.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\10.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\100.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\101.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\102.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\103.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\104.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\105.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\106.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\107.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\108.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\109.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\11.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\110.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\111.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\112.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\113.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\114.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\115.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\116.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\117.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\118.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\119.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\12.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\120.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\121.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\122.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\123.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\124.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\125.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\126.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\127.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\128.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\129.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\13.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\130.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\131.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\132.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\133.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\134.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\135.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\136.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\137.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\138.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\139.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\14.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\140.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\141.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\142.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\143.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\144.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\145.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\146.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\147.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\148.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\149.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\15.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\150.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\151.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\152.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\153.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\154.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\155.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\156.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\157.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\158.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\159.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\16.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\160.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\161.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\162.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\163.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\164.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\165.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\166.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\167.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\168.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\169.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\17.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\170.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\171.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\172.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\173.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\174.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\175.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\176.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\177.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\178.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\179.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\18.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\180.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\181.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\182.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\183.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\184.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\185.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\186.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\187.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\188.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\189.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\19.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\190.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\191.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\192.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\193.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\194.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\195.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\196.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\197.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\198.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\199.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\2.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\20.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\200.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\201.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\202.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\203.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\204.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\205.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\206.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\207.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\208.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\209.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\21.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\210.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\211.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\212.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\213.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\214.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\215.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\216.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\217.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\218.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\219.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\22.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\220.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\221.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\222.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\223.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\224.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\225.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\226.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\227.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\228.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\229.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\23.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\230.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\231.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\232.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\233.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\234.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\235.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\236.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\237.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\238.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\239.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\24.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\240.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\241.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\242.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\243.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\244.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\245.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\246.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\247.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\248.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\249.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\25.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\26.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\27.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\28.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\29.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\3.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\30.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\31.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\32.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\33.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\34.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\35.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\36.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\37.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\38.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\39.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\4.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\40.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\41.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\42.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\43.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\44.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\45.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\46.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\47.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\48.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\49.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\5.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\50.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\51.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\52.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\53.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\54.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\55.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\56.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\57.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\58.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\59.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\6.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\60.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\61.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\62.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\63.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\64.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\65.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\66.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\67.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\68.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\69.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\7.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\70.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\71.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\72.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\73.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\74.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\75.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\76.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\77.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\78.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\79.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\8.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\80.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\81.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\82.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\83.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\84.gz',
#    'labels': {'hit_label': ['beater'],
#     'kit_label': ['bass_drum'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\beater\\bass_drum\\normal\\85.gz',
# ...
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\365.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\366.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\37.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\38.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\39.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\4.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\40.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\41.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\42.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\43.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\44.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\45.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\46.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\47.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\48.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\49.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\5.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\50.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\51.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\52.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\53.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\54.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\55.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\56.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\57.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\58.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\59.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\6.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\60.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\61.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\62.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\63.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\64.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\65.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\66.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\67.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\68.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\69.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\7.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\70.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\71.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\72.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\73.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\74.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\75.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\76.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\77.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\78.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\79.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\8.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\80.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\81.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\82.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\83.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\84.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\85.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\86.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\87.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\88.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\89.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\9.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\90.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\91.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\92.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\93.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\94.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\95.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\96.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\97.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\98.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\snare\\normal\\99.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['snare'],
#     'tech_label': ['normal']}}],
#  'splash-normal': [{'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\splash\\normal\\0.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['splash'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\splash\\normal\\1.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['splash'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\splash\\normal\\10.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['splash'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\splash\\normal\\2.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['splash'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\splash\\normal\\3.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['splash'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\splash\\normal\\4.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['splash'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\splash\\normal\\5.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['splash'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\splash\\normal\\6.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['splash'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\splash\\normal\\7.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['splash'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\splash\\normal\\8.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['splash'],
#     'tech_label': ['normal']}},
#   {'augmentations': {},
#    'filepath': 'audio_data\\cropped_data\\stick\\splash\\normal\\9.gz',
#    'labels': {'hit_label': ['stick'],
#     'kit_label': ['splash'],
#     'tech_label': ['normal']}}]}

# %%
{kltl: len(fd_categorised_no_augs[kltl]) for kltl in hit_breakdown["beater"]+hit_breakdown["stick"]}
# Out:
# {'bass_drum-normal': 250,
#  'crash-normal': 12,
#  'hi_hat-normal': 49,
#  'hi_hat-open': 36,
#  'high_tom-normal': 20,
#  'low_tom-normal': 22,
#  'mid_tom-normal': 27,
#  'ride-bell': 10,
#  'ride-normal': 12,
#  'snare-normal': 367,
#  'splash-normal': 11}

# %%
## Multiclassed -- (on cropped data which wasn't augmented)
kltl_iterations = {kltl: 0 for kltl in hit_breakdown["beater"]+hit_breakdown["stick"]}
multiclassed_data_no_augs = []
for kit_combo_set in kcs:
    kc = [kltl for kltl in kit_combo_set]
    kc.sort()
    samples = np.zeros(12000, dtype=np.float32)
    labels=dict()
    for kltl in kc:
        file_i = kltl_iterations[kltl]
        fd = fd_categorised_no_augs[kltl][file_i]
        filepath = fd["filepath"]
        try:
            new_samples = np.loadtxt(fname=filepath, dtype=np.float32)
            pad_len = 12000-len(new_samples)
            new_samples = np.pad(new_samples, (pad_len, 0), "constant", constant_values=(0))
            samples = samples + new_samples
            kltl_iterations[kltl] = (kltl_iterations[kltl] + 1) % len(fd_categorised_no_augs[kltl])
        except:
            print("skipped", *sys.exc_info())
            continue
        for l in LABELS:
            if (l not in labels.keys() and l in fd["labels"].keys()):
                labels.update({l: [x for x in fd["labels"][l]]})
            elif (l in fd["labels"].keys()):
                labels.update({l: labels[l]+fd["labels"][l]})
    multiclassed_data_no_augs.append(Sample_data(labels={k:v for k,v in labels.items()}, data=samples, rate=SETTINGS.data["cropped"]["save_sampling_rate"]))
save_data("multiclassed_no_augs", data_set=multiclassed_data_no_augs, verbose=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-421e2a828236> in <module>
#       1 ## Multiclassed -- (on cropped data which wasn't augmented)
# ----> 2 kltl_iterations = {kltl: 0 for kltl in hit_breakdown["beater"]+hit_breakdown["stick"]}
#       3 multiclassed_data_no_augs = []
#       4 for kit_combo_set in kcs:
#       5     kc = [kltl for kltl in kit_combo_set]
#
# NameError: name 'hit_breakdown' is not defined

# %%
a = np.zeros(12)
len(a)
# Out:
# 12

# %%
a
# Out:
# 11988
# array([1., 1., 1., ..., 0., 0., 0.])

# %%
len(a)
# Out:
# 12000
