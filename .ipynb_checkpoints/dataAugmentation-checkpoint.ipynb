# %%
import sys
import collections
import numpy as np
from scipy.signal import savgol_filter, convolve, normalize
import IPython.display as ipd
import matplotlib.pyplot as plt
import librosa
import time

# Allows me to import my modules
sys.path.append('./modules')
from audio_utils import *
import data_augmentation as data_aug
# Out:
# Attempting to read settings file...
# 	Read successfully!

# %%
file_i = 7

# %%
samples = read_data(data_type="cropped", file_index=file_i, batch_size=5, kit_label=["hi_hat"], tech_label=["normal"], verbose=True)
print(len(samples) if samples is not False else 0)
file_i += 1
# Out:
# Attempting to read 5 cropped data and labels (from index 8 )...
# 	Only{'tech_label': ['normal'], 'kit_label': ['hi_hat']}
# 	Read: 5/5 (49 files found).
# 5

# %%
plt.plot(samples[0].data)
plt.show()
ipd.Audio(samples[0].data, rate=samples[0].rate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.plot(samples[1].data)
plt.show()
ipd.Audio(samples[1].data, rate=samples[1].rate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.plot(samples[2].data)
plt.show()
ipd.Audio(samples[2].data, rate=samples[2].rate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.plot(samples[3].data)
plt.show()
ipd.Audio(samples[3].data, rate=samples[3].rate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.plot(samples[4].data)
plt.show()
ipd.Audio(samples[4].data, rate=samples[4].rate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
augmented_samples = data_aug.pre_multiclass_augmentation(samples)
# Out:
# Processing augmented data - 0/5 (0.0%)
# Processing augmented data - 1/5 (20.0%)
# Processing augmented data - 2/5 (40.0%)
# Processing augmented data - 3/5 (60.0%)
# Processing augmented data - 4/5 (80.0%)
# Time taken: 2.08

# %%
aug_stacks = data_aug.get_aug_stacks(data_aug.PRE_MULTI_AUGS)
# Create new augmentation data ordered dictionary
aug_data = collections.OrderedDict([("-".join(stack), []) for stack in aug_stacks])
aug_keys = list(aug_data.keys())

# %%
augmented_sample_data = []
for s in range(len(samples)):
    for stack_key in aug_keys:
        aug_amount = len(augmented_samples[s][stack_key])
        augs = stack_key.split("-")
        for d in range(aug_amount):
            augmented_sample_data.append(Sample_data(labels=samples[s].labels, augmentations=augs, rate=samples[s].rate, data=augmented_samples[s][stack_key][d]))

# %%
for asd in augmented_sample_data:
    print("Labels: {}\n\nAugmentations: {}\n\n".format(asd.labels, asd.augmentations))
# Out:
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# ...
#
# Augmentations: ['amplitude']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']
#
#
# Labels: {'hit_label': ['stick'], 'tech_label': ['normal'], 'kit_label': ['hi_hat']}
#
# Augmentations: ['amplitude', 'pitch', 'translate']

# %%
save_data("pre_multiclass_augmented", data_set=augmented_sample_data, verbose=True)
# Out:
# Attempting to save pre_multiclass_augmented data and labels...
# 	Saved: 620/620 files.
# True

# %%
for stack_key in aug_keys:
    aug_amount = len(augmented_samples[0][stack_key])
    for d in range(aug_amount):
        plt.plot(augmented_samples[0][stack_key][d])
        plt.title("{} diff: {}".format(stack_key, d))
        plt.show()

# %%
ipd.Audio(samples[0].data, rate=samples[0].rate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(augmented_samples[0]["pitch"][0], rate=samples[0].rate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(augmented_samples[0]["pitch"][-1], rate=samples[0].rate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(augmented_samples[0]["translate"][0], rate=samples[0].rate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(augmented_samples[0]["translate"][-1], rate=samples[0].rate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.plot(samples[0].data, color="blue")
plt.show()

# %%
plt.plot(samples[0].data, color="blue")
plt.plot(augmented_samples[0]["amplitude"][0], color="grey")
plt.show()

# %%
plt.plot(samples[0].data, color="blue")
plt.plot(augmented_samples[0]["pitch"][-1], color="grey")
plt.show()

# %%
plt.plot(samples[0].data, color="blue")
plt.plot(augmented_samples[0]["translate"][-1], color="grey")
plt.show()
