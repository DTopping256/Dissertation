# %%
! pip install scipy

# %%
import matplotlib.pyplot as plt
from matplotlib.axes import Axes
from scipy import signal
from scipy.io import wavfile as wav

# %%
labelled_files = [{"path": "./raw_data/isolated_hits/stick/crash/normal/0.wav", "label": "crash"}, {"path": "./raw_data/isolated_hits/stick/low_tom/normal/0.wav", "label": "low_tom"}, {"path": "./raw_data/isolated_hits/stick/mid_tom/normal/0.wav", "label": "mid_tom"},{"path": "./raw_data/isolated_hits/stick/high_tom/normal/0.wav", "label": "high_tom"},{"path": "./raw_data/isolated_hits/stick/hi_hat/normal/0.wav", "label": "hi_hat"}, {"path": "./raw_data/isolated_hits/beater/bass_drum/normal/0.wav", "label": "bass_drum"}, {"path": "./raw_data/isolated_hits/stick/snare/normal/0.wav", "label": "snare"}, {"path": "./raw_data/isolated_hits/stick/ride/normal/0.wav", "label": "ride"}, {"path": "./raw_data/isolated_hits/stick/snare/rim_click/0.wav", "label": "snare_rim_click"}, {"path": "./raw_data/isolated_hits/stick/snare/rim_shot/0.wav", "label": "snare_rim_shot"}, {"path": "./raw_data/isolated_hits/stick/snare/rolls/0.wav", "label": "snare_rolls"}, {"path": "./raw_data/isolated_hits/stick/ride/bell/0.wav", "label": "ride_bell"}]
labelled_files.sort(key=lambda x: x["label"])
print(labelled_files)
# Out:
# [{'path': './raw_data/isolated_hits/beater/bass_drum/normal/0.wav', 'label': 'bass_drum'}, {'path': './raw_data/isolated_hits/stick/crash/normal/0.wav', 'label': 'crash'}, {'path': './raw_data/isolated_hits/stick/hi_hat/normal/0.wav', 'label': 'hi_hat'}, {'path': './raw_data/isolated_hits/stick/high_tom/normal/0.wav', 'label': 'high_tom'}, {'path': './raw_data/isolated_hits/stick/low_tom/normal/0.wav', 'label': 'low_tom'}, {'path': './raw_data/isolated_hits/stick/mid_tom/normal/0.wav', 'label': 'mid_tom'}, {'path': './raw_data/isolated_hits/stick/ride/normal/0.wav', 'label': 'ride'}, {'path': './raw_data/isolated_hits/stick/ride/bell/0.wav', 'label': 'ride_bell'}, {'path': './raw_data/isolated_hits/stick/snare/normal/0.wav', 'label': 'snare'}, {'path': './raw_data/isolated_hits/stick/snare/rim_click/0.wav', 'label': 'snare_rim_click'}, {'path': './raw_data/isolated_hits/stick/snare/rim_shot/0.wav', 'label': 'snare_rim_shot'}, {'path': './raw_data/isolated_hits/stick/snare/rolls/0.wav
# ...

# %%
def read_raw_data():
    output = []
    for file in labelled_files:
        s_rate, samples = wav.read(file["path"])
        output.append((file["label"], samples, s_rate))
    return output

# %%
data = read_raw_data()

# %%
def plot(title, samples, sample_rate):
    # Plot the signal read from wav file
    
    plt.subplot(211)

    plt.title(title)

    a = plt.plot(samples)
    
    plt.xlabel('Sample')

    plt.ylabel('Amplitude')

    plt.subplot(212)

    plt.specgram(samples, Fs=sample_rate)
    
    plt.ylim((0, 30000))

    plt.xlabel('Time')

    plt.ylabel('Frequency')

    plt.show()

# %%
for d in data:
    plot(*d)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\users\danzi\appdata\local\programs\python\python35\lib\site-packages\matplotlib\cbook\__init__.py in index_of(y)
#    1617     try:
# -> 1618         return y.index.values, y.values
#    1619     except AttributeError:
#
# AttributeError: 'numpy.ndarray' object has no attribute 'index'
#
# During handling of the above exception, another exception occurred:
#
# MemoryError                               Traceback (most recent call last)
# <ipython-input-57-25019f62e48e> in <module>
#       1 for d in data:
# ----> 2     plot(*d)
#
# <ipython-input-54-b25c727a3a57> in plot(title, samples, sample_rate)
#       6     plt.title(title)
#       7
# ----> 8     a = plt.plot(samples)
#       9
#      10     plt.xlabel('Sample')
#
# ...

# %%
plot("crash (segment)", data[1][1][970000:1400000], data[1][2])

# %%
data[1][1][1000000:1000009]
# Out:
# array([14, 20, 28, 35, 42, 46, 50, 53, 54], dtype=int16)
